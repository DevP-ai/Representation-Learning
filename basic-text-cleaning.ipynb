# %% [markdown]
# <a href="https://www.kaggle.com/code/devajitpatar/basic-text-cleaning?scriptVersionId=112859061" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # **Removing HTML Tags**

# %%
sample_text='<h1>Kaggle</h1><p>Grow your data<code class="w3-codespan">&lt;sup&gt;</code> science skills by competing in our exciting competitions. Find help in the documentation or learn about Community Competitions.</p>'

# %%
sample_text
# Out:
# '<h1>Kaggle</h1><p>Grow your data<code class="w3-codespan">&lt;sup&gt;</code> science skills by competing in our exciting competitions. Find help in the documentation or learn about Community Competitions.</p>'

# %%
import re

def striphtml(data):
    p=re.compile(r'<.*?>')
    return p.sub('',data)

# %%
striphtml(sample_text)
# Out:
# 'KaggleGrow your data&lt;sup&gt; science skills by competing in our exciting competitions. Find help in the documentation or learn about Community Competitions.'

# %% [markdown]
# # **Unicode Normalization/Emoji Remove**

# %%
emojis_text='The 👒 Hat Emoji And Other Cool 👠​ Fashion Emojis To Level Up Your #OOTD Posts And Be A 🧥​ Digital Fashionista.Celebrate 🍂 Fall With The 🍃 Leaf Emoji And DIY Craft Ideas You Can Do With Leaves 🍁'

# %%
emojis_text
# Out:
# 'The 👒 Hat Emoji And Other Cool 👠\u200b Fashion Emojis To Level Up Your #OOTD Posts And Be A 🧥\u200b Digital Fashionista.Celebrate 🍂 Fall With The 🍃 Leaf Emoji And DIY Craft Ideas You Can Do With Leaves 🍁'

# %%
emojis_text.encode('Utf-8')
# Out:
# b'The \xf0\x9f\x91\x92 Hat Emoji And Other Cool \xf0\x9f\x91\xa0\xe2\x80\x8b Fashion Emojis To Level Up Your #OOTD Posts And Be A \xf0\x9f\xa7\xa5\xe2\x80\x8b Digital Fashionista.Celebrate \xf0\x9f\x8d\x82 Fall With The \xf0\x9f\x8d\x83 Leaf Emoji And DIY Craft Ideas You Can Do With Leaves \xf0\x9f\x8d\x81'

# %% [markdown]
# # **Spelling Check**

# %%
incorrect_text='Till the year 1980, natural longuage processing systems were based on cmplx sets of hand-writen rles. After 1980, NLP introduced machine learning algorith for longuage processing.'

# %%
incorrect_text
# Out:
# 'Till the year 1980, natural longuage processing systems were based on cmplx sets of hand-writen rles. After 1980, NLP introduced machine learning algorith for longuage processing.'

# %%
from textblob import TextBlob

textBlb=TextBlob(incorrect_text)

textBlb.correct()
# Out:
# TextBlob("Will the year 1980, natural language processing systems were based on complex sets of hand-written rules. After 1980, NLP introduced machine learning algorith for language processing.")

# %% [markdown]
# # **Tokenization**

# %%
dummy="""The institute was established by the International Institute of Information Technology University Act,2013 of the Government of Chhattisgarh, is a joint venture of Government of Chhattisgarh and NTPC Ltd. It is a State University recognized by University Grants Commission, New Delhi.IIIT-NR currently runs several undergraduate programs for B.Tech. degree, Postgraduate M. Tech and MS(R) programmes. In addition, it also offers Ph.D programs in various fields."""

# %%
dummy
# Out:
# 'The institute was established by the International Institute of Information Technology University Act,2013 of the Government of Chhattisgarh, is a joint venture of Government of Chhattisgarh and NTPC Ltd. It is a State University recognized by University Grants Commission, New Delhi.IIIT-NR currently runs several undergraduate programs for B.Tech. degree, Postgraduate M. Tech and MS(R) programmes. In addition, it also offers Ph.D programs in various fields.'

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
sentence=sent_tokenize(dummy)
sentence
# Out:
# ['The institute was established by the International Institute of Information Technology University Act,2013 of the Government of Chhattisgarh, is a joint venture of Government of Chhattisgarh and NTPC Ltd.',
#  'It is a State University recognized by University Grants Commission, New Delhi.IIIT-NR currently runs several undergraduate programs for B.Tech.',
#  'degree, Postgraduate M. Tech and MS(R) programmes.',
#  'In addition, it also offers Ph.D programs in various fields.']

# %%
for sent in sentence:
    print(word_tokenize(sent))
# Out:
# ['The', 'institute', 'was', 'established', 'by', 'the', 'International', 'Institute', 'of', 'Information', 'Technology', 'University', 'Act,2013', 'of', 'the', 'Government', 'of', 'Chhattisgarh', ',', 'is', 'a', 'joint', 'venture', 'of', 'Government', 'of', 'Chhattisgarh', 'and', 'NTPC', 'Ltd', '.']
# ['It', 'is', 'a', 'State', 'University', 'recognized', 'by', 'University', 'Grants', 'Commission', ',', 'New', 'Delhi.IIIT-NR', 'currently', 'runs', 'several', 'undergraduate', 'programs', 'for', 'B.Tech', '.']
# ['degree', ',', 'Postgraduate', 'M.', 'Tech', 'and', 'MS', '(', 'R', ')', 'programmes', '.']
# ['In', 'addition', ',', 'it', 'also', 'offers', 'Ph.D', 'programs', 'in', 'various', 'fields', '.']
